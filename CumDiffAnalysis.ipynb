# %%
import numpy as np # for math
import pandas as pd # to load the spreadsheet
from matplotlib import pyplot as plt # for plotting

# %%
#Unaveraged 38 samples from main transect

# this line imports the data from the spreadsheet and saves it as an array
cumdiffdata = np.asarray(pd.read_csv('Data/datatest.csv'))

# these lines save every other column starting from the 0th column as the horizontal distace (dvals) and every other column starting from the 1st column as elevation (zvals), for the raw data in qgisdata
vvals = cumdiffdata[:,1::2]
gvals = cumdiffdata[:,::2]

# %%
plt.plot(gvals, vvals)
plt.xscale('log')
plt.xlabel('grain size (um)')
plt.ylabel('cum. volume(%)')
plt.show()

# %%
#Averaged 38 samples from main transect

avgcumdiffdata = np.asarray(pd.read_csv('Data/JupNot_CumDiff_Avg.csv'))

svals = avgcumdiffdata[:,1::2]
gsvals = avgcumdiffdata[:,::2]

# %%
plt.plot(gsvals, svals)
plt.xscale('log')
plt.xlabel('grain size (um)')
plt.ylabel('cum. volume(%)')
plt.show()

# %%
# Sample D50 vs. Horizontal Distance (from bottom of the hill)

import numpy as np # for math
import pandas as pd # to load the spreadsheet
from matplotlib import pyplot as plt # for plotting

avgsample_d50_data = np.asarray(pd.read_csv('Data/Sample_D50_good.csv'))

svals = avgsample_d50_data[:,1::2]
dvals = avgsample_d50_data[:,::2]

# %%
plt.plot(svals, dvals)
plt.xlabel('Horizontal Distance (from bottom of the hill), (m)')
plt.ylabel('Sample D50 (um)')
plt.show()
